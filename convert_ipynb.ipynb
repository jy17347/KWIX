# %%
import os
import pandas as pd

data_dir = "./dataset/trainset"

for root, dirs, files in os.walk(data_dir):
    for file in files:
        print(root)
        xlsx = pd.read_excel(f'{root}/{file}')
        xlsx.to_csv(f"{root}/{file[:-4]}csv")
    #     if file == myfile:
    #         print(file)
# Out:
# ./dataset/trainset\hor
# ./dataset/trainset\hor
# ./dataset/trainset\hor
# ./dataset/trainset\hor
# ./dataset/trainset\hor
# ./dataset/trainset\hor
# ./dataset/trainset\ld
# ./dataset/trainset\ld
# ./dataset/trainset\ld
# ./dataset/trainset\ld
# ./dataset/trainset\ld
# ./dataset/trainset\ld
# ./dataset/trainset\lu
# ./dataset/trainset\lu
# ./dataset/trainset\lu
# ./dataset/trainset\lu
# ./dataset/trainset\lu
# ./dataset/trainset\lu
# ./dataset/trainset\mc
# ./dataset/trainset\mc
# ./dataset/trainset\mc
# ./dataset/trainset\mc
# ./dataset/trainset\mc
# ./dataset/trainset\mc
# ./dataset/trainset\ms
# ./dataset/trainset\ms
# ./dataset/trainset\ms
# ./dataset/trainset\ms
# ./dataset/trainset\ms
# ./dataset/trainset\ms
# ./dataset/trainset\oc
# ./dataset/trainset\oc
# ./dataset/trainset\oc
# ./dataset/trainset\oc
# ./dataset/trainset\oc
# ./dataset/trainset\oc
# ./dataset/trainset\os
# ./dataset/trainset\os
# ./dataset/trainset\os
# ./dataset/trainset\os
# ./dataset/trainset\os
# ...
